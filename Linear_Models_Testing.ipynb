# %% [markdown]
# <a href="https://colab.research.google.com/github/Andrew-Calix/Machine-Learning/blob/main/Linear_Models_Testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/test.csv")
df.head()
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X, y = df.iloc[:, :-1], df.iloc[:, -1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

lr = LinearRegression().fit(X_train, y_train)
print("training score: {:.2f}".format(lr.score(X_train,y_train)))
print("test score: {:.2f}".format(lr.score(X_test,y_test)))
# Out:
# training score: 0.99
# test score: 0.99

# %%
from sklearn.linear_model import Ridge

ridge = Ridge().fit(X_train, y_train)
print("ridge training: {:.2f}".format(ridge.score(X_train, y_train)))
print("ridge testing: {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# ridge training: 0.99
# ridge testing: 0.99
